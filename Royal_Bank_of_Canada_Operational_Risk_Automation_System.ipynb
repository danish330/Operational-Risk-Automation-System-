# %% [markdown]
# <a href="https://colab.research.google.com/github/danish330/Royal-Bank-of-Canada-Operational-Risk-Automation-System-/blob/main/Royal_Bank_of_Canada_Operational_Risk_Automation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================
# RBC Operational Risk Simulation Dashboard
# Author: Danish Aizzat
# =========================================

# Step 1: Setup
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns


# Step 2: Read CSV
csv_url = "https://raw.githubusercontent.com/danish330/Royal-Bank-of-Canada-Operational-Risk-Automation-System-/refs/heads/main/RBC_Trade_Matching_Mock_Data.csv"
df = pd.read_csv(csv_url)


# Step 3: Clean & transform data
df['Match_Time'] = pd.to_datetime(df['Match_Time'], format='%H:%M', errors='coerce').dt.time
df['Match_Hour'] = pd.to_datetime(df['Match_Time'], format='%H:%M:%S', errors='coerce').dt.hour
df['Match_Hour'] = df['Match_Hour'].fillna(-1)

# Simulate EOD trade risk (after 3PM)
df["EOD_Risk"] = np.where(
    (df["Match_Status"] == "Matched Late") & (df["Match_Hour"] >= 15),
    "YES – Escalate", "No"
)

# Simulate Confirmation Tracer
df["Confirmation_Status"] = np.where(
    df["Match_Status"] == "Unmatched", "Pending – Send Tracer", "Confirmed"
)

# Simulate Allocation Status for CTM
df["Allocation_Flag"] = np.where(
    df["CTM_Allocated"] == "No", "Incomplete – Follow Up", "Allocated"
)

# Step 4: KPI Summary
print("\n===== 🧾 RBC Operational KPIs =====")
print(f"Total Trades: {len(df)}")
print(f"Matched: {df[df['Match_Status'] == 'Matched'].shape[0]}")
print(f"Unmatched: {df[df['Match_Status'] == 'Unmatched'].shape[0]}")
print(f"Matched Late: {df[df['Match_Status'] == 'Matched Late'].shape[0]}")
print(f"Late After EOD (3PM): {df[df['EOD_Risk'] == 'YES – Escalate'].shape[0]}")
print(f"CTM Allocated – Yes: {df[df['CTM_Allocated'] == 'Yes'].shape[0]}")
print(f"CTM Allocated – No: {df[df['CTM_Allocated'] == 'No'].shape[0]}")
print(f"Pending Confirmations: {df[df['Confirmation_Status'] == 'Pending – Send Tracer'].shape[0]}")

# Step 5: Match Status Pie Chart
fig1 = px.pie(df, names='Match_Status', title='✅ Trade Match Status')
fig1.show()

# Step 6: Unmatched & Late Trades by Date
unmatched = df[df['Match_Status'] != 'Matched']
trend_data = unmatched.groupby('Trade_Date').size().reset_index(name='Trade_Issues')
fig2 = px.bar(trend_data, x='Trade_Date', y='Trade_Issues', title='📅 Unmatched or Late Trades by Date')
fig2.show()

# Step 7: CTM Allocation Chart
fig3 = px.pie(df, names='CTM_Allocated', title='📤 CTM Allocation Status')
fig3.show()

# Step 8: Trades by Trader & Match Status
fig4 = px.histogram(df, x='Trader_Name', color='Match_Status',
                    barmode='group', title='🧑‍💼 Trades by Trader & Match Status')
fig4.show()

# Step 9: Counterparty Confirmation Analysis
fig5 = px.histogram(df, x='Counterparty', color='Confirmation_Status',
                    barmode='group', title='🏦 Counterparty Confirmation Tracker')
fig5.show()

# Step 10: Risk Escalation Report (Late after 3PM)
print("\n📣 Trades Matched After 3PM (EOD Breach)")
df[df["EOD_Risk"] == "YES – Escalate"][["Trade_ID", "Trade_Date", "Match_Time", "Trader_Name", "Counterparty"]]

# Step 11: Full Operational Trade Table (Audit Log)
print("\n📋 Full Trade Audit Log:")
df_full = df[["Trade_ID", "Trade_Date", "Match_Status", "CTM_Allocated", "Match_Time",
              "EOD_Risk", "Confirmation_Status", "Trader_Name", "Counterparty"]]
df_full.head(20)
# Out:
# ===== 🧾 RBC Operational KPIs =====
# Total Trades: 100
# Matched: 38
# Unmatched: 28
# Matched Late: 34
# Late After EOD (3PM): 11
# CTM Allocated – Yes: 51
# CTM Allocated – No: 49
# Pending Confirmations: 28
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d194cae0-cfd7-4e4e-8701-e110656f5301" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d194cae0-cfd7-4e4e-8701-e110656f5301")) {                    Plotly.newPlot(                        "d194cae0-cfd7-4e4e-8701-e110656f5301",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Match_Status=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Unmatched","Matched Late","Matched","Matched Late","Unmatched","Matched","Matched","Matched","Matched Late","Matched","Matched","Matched Late","Matched","Matched","Matched","Matched Late","Matched Late","Matched","Unmatched","Unmatched","Matched Late","Matched","Matched Late","Unmatched","Unmatched","Unmatched","Unmatched","Unmatched","Unmatched","Matched Late","Matched","Matched Late","Matched Late","Unmatched","Matched","Unmatched","Unmatched","Matched","Matched","Matched Late","Matched","Matched","Matched","Matched Late","Matched","Unmatched","Unmatched","Unmatched","Matched Late","Matched","Matched Late","Unmatched","Unmatched","Matched Late","Matched Late","Matched Late","Matched","Unmatched","Matched","Matched Late","Matched Late","Unmatched","Matched Late","Matched","Matched Late","Unmatched","Matched","Unmatched","Matched Late","Matched","Matched","Matched Late","Matched Late","Matched","Matched Late","Unmatched","Matched","Matched Late","Matched","Matched Late","Unmatched","Unmatched","Matched","Matched","Matched Late","Unmatched","Matched","Matched","Matched Late","Matched","Matched Late","Matched","Matched Late","Matched Late","Matched","Matched","Matched","Unmatched","Matched Late","Unmatched"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="01c42b80-b60a-4c55-81b1-971b364519de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01c42b80-b60a-4c55-81b1-971b364519de")) {                    Plotly.newPlot(                        "01c42b80-b60a-4c55-81b1-971b364519de",                        [{"alignmentgroup":"True","hovertemplate":"Trade_Date=%{x}\u003cbr\u003eTrade_Issues=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2022-07-01","2022-07-02","2022-07-03","2022-07-04","2022-07-06","2022-07-08","2022-07-09","2022-07-11","2022-07-12","2022-07-13","2022-07-14","2022-07-15","2022-07-16","2022-07-17","2022-07-18","2022-07-19","2022-07-20","2022-07-22","2022-07-23","2022-07-24","2022-07-27","2022-07-28","2022-07-29","2022-07-30","2022-07-31"],"xaxis":"x","y":[1,1,2,6,6,2,5,2,1,3,2,2,4,3,3,2,1,2,2,2,1,2,3,1,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatter ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b222ae5a-298d-4e5c-b553-ef6e8d4a0017" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b222ae5a-298d-4e5c-b553-ef6e8d4a0017")) {                    Plotly.newPlot(                        "b222ae5a-298d-4e5c-b553-ef6e8d4a0017",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"CTM_Allocated=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"s ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ba824982-fb8b-457b-982a-0ba307943c32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba824982-fb8b-457b-982a-0ba307943c32")) {                    Plotly.newPlot(                        "ba824982-fb8b-457b-982a-0ba307943c32",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Match_Status=Unmatched\u003cbr\u003eTrader_Name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unmatched","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Unmatched","offsetgroup":"Unmatched","orientation":"v","showlegend":true,"x":["Aizzat","Nurul","Nurul","Ali","Nurul","Ali","Sarah","Nurul","Nurul","Ali","Nurul","Aizzat","Nurul","Nurul","Sarah","Aizzat","Nurul","Nurul","Sarah","Nurul","Amir","Nurul","Nurul","Amir","Ali","Aizzat","Ali","Sarah"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Match_Status=Matched Late\u003cbr\u003eTrader_Name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Matched Late","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Matched Late","offsetgroup":"Matched Late","orientation":"v","showlegend":true,"x":["Ali","Ali","Amir","Nurul","Amir","Ali","Sarah","Sarah","Ali","Nurul","Ali","Ali","Sarah","Ali","Nurul","Amir","Amir","Amir","Aizzat","Sarah","Aizzat","Nurul","Nurul","Ali","Ali","Sarah","Sarah","Aizzat","Ali","Sarah","Sarah","Ali","Aizzat","Amir"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Match_Status=Matched\u003cbr\u003eTrader_Name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Matched","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Matched","offsetgroup":"Matched","orientation":"v","showlegend":true,"x":["Amir","Ali","Sarah","Aizzat","Nurul","Aizzat","Amir","Nurul","Nurul","Sarah","Sarah","Amir","Sarah","Ali","Amir","Ali","Nurul","Sarah","Amir","Nurul","Aizzat","Nurul","Sarah","Nurul","Amir","Sarah","Amir","Sarah","Amir","Sarah","Ali","Nurul","Amir","Sarah","Amir","Nurul","Ali","Sarah"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="814142aa-15b7-45e5-aa9a-9bb904a774d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("814142aa-15b7-45e5-aa9a-9bb904a774d3")) {                    Plotly.newPlot(                        "814142aa-15b7-45e5-aa9a-9bb904a774d3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Confirmation_Status=Pending – Send Tracer\u003cbr\u003eCounterparty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pending – Send Tracer","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Pending – Send Tracer","offsetgroup":"Pending – Send Tracer","orientation":"v","showlegend":true,"x":["HSBC","Goldman Sachs","Goldman Sachs","Citi","Goldman Sachs","Goldman Sachs","Morgan Stanley","HSBC","Goldman Sachs","Morgan Stanley","Citi","JPMorgan","Citi","Morgan Stanley","Goldman Sachs","Citi","Citi","Morgan Stanley","Morgan Stanley","JPMorgan","HSBC","Goldman Sachs","Morgan Stanley","Goldman Sachs","Morgan Stanley","HSBC","Citi","Citi"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Confirmation_Status=Confirmed\u003cbr\u003eCounterparty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Confirmed","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Confirmed","offsetgroup":"Confirmed","orientation":"v","showlegend":true,"x":["Morgan Stanley","HSBC","Citi","Goldman Sachs","Citi","Morgan Stanley","Goldman Sachs","Morgan Stanley","JPMorgan","Morgan Stanley","JPMorgan","HSBC","Goldman Sachs","HSBC","Morgan Stanley","JPMorgan","Citi","HSBC","Goldman Sachs","Goldman Sachs","Morgan Stanley","JPMorgan","Morgan Stanley","HSBC","Morgan Stanley","Goldman Sachs","JPMorgan","Goldman Sachs","HSBC","Morgan Stanley","Goldman Sachs","Citi","Morgan Stanley","HSBC","JPMorgan","HSBC","JPMorgan","Citi","Citi","JPMorgan","HSBC","HSBC","Citi","Goldman Sachs","JPMorgan","Goldman Sachs","JPMorgan","Goldman Sachs","Goldman Sachs","JPMorgan","Morgan Stanley","HSBC","Citi","Goldman Sachs","JPMorgan","Goldman Sachs","JPMorgan","Goldman Sachs","Morgan Stanley","JPMorgan","HSBC","HSBC","Citi","HSBC","HSBC","HSBC","Morgan Stanley","Citi","Goldman Sachs","Citi","Goldman Sachs","Morgan Stanley"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222 ...
# 📣 Trades Matched After 3PM (EOD Breach)
#
# 📋 Full Trade Audit Log:
#    Trade_ID  Trade_Date  Match_Status CTM_Allocated Match_Time  \
# 0     T1000  2022-07-18     Unmatched           Yes   14:06:00
# 1     T1001  2022-07-06  Matched Late           Yes   10:07:00
# 2     T1002  2022-07-04       Matched            No   08:17:00
# 3     T1003  2022-07-19  Matched Late            No   12:03:00
# 4     T1004  2022-07-29     Unmatched            No   17:31:00
# 5     T1005  2022-07-26       Matched           Yes   12:26:00
# 6     T1006  2022-07-19       Matched           Yes   16:22:00
# 7     T1007  2022-07-21       Matched            No   11:11:00
# 8     T1008  2022-07-24  Matched Late           Yes   11:13:00
# 9     T1009  2022-07-05       Matched            No   11:48:00
# 10    T1010  2022-07-22       Matched           Yes   10:11:00
# 11    T1011  2022-07-31  Matched Late            No   17:09:00
# 12    T1012  2022-07-27       Matched            No   14:05:00
# 13    T1013  2022-07-18       Matched           Yes   14:39:00
# 14    T1014  2022-07-10       Matched            No   17:47:00
# 15    T1015  2022-07-09  Matched Late           Yes   17:24:00
# 16    T1016  2022-07-18  Matched Late            No   14:26:00
# 17    T1017  2022-07-15       Matched           Yes   09:19:00
# 18    T1018  2022-07-28     Unmatched           Yes   10:16:00
# 19    T1019  2022-07-04     Unmatched           Yes   16:39:00
#
#           EOD_Risk    Confirmation_Status Trader_Name    Counterparty
# 0               No  Pending – Send Tracer      Aizzat            HSBC
# 1               No              Confirmed         Ali  Morgan Stanley
# 2               No              Confirmed        Amir            HSBC
# 3               No              Confirmed         Ali            Citi
# 4               No  Pending – Send Tracer       Nurul   Goldman Sachs
# 5               No              Confirmed         Ali   Goldman Sachs
# 6               No              Confirmed       Sarah            Citi
# 7               No              Confirmed      Aizzat  Morgan Stanley
# 8               No              Confirmed        Amir   Goldman Sachs
# 9               No              Confirmed       Nurul  Morgan Stanley
# 10              No              Confirmed      Aizzat        JPMorgan
# 11  YES – Escalate              Confirmed       Nurul  Morgan Stanley
# 12              No              Confirmed        Amir        JPMorgan
# 13              No              Confirmed       Nurul            HSBC
# 14              No              Confirmed       Nurul   Goldman Sachs
# 15  YES – Escalate              Confirmed        Amir            HSBC
# 16              No              Confirmed         Ali  Morgan Stanley
# 17              No              Confirmed       Sarah        JPMorgan
# 18              No  Pending – Send Tracer       Nurul   Goldman Sachs
# 19              No  Pending – Send Tracer         Ali            Citi
